# %%
from agents import EventAgent

# %% [markdown]
# agent = EventAgent()

# %%
agent.plan_event(
    event_type="Wedding",
    date="2025-12-20",
    budget=60000,
    guests=200
)

# %%
agent.refine_plan({"budget": 45000})

# %%
agent.show_memory()
